# %%
# !git clone https://github.com/MRoberto25/fashion_mnist_pro
# Out:
# Cloning into 'fashion_mnist_pro'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 78 (delta 32), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 28.97 KiB | 1.52 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !ls -la
# Out:
# total 52
# drwxr-xr-x 7 root root 4096 May 31 19:22 .
# drwxr-xr-x 4 root root 4096 May 31 19:22 ..
# -rw-r--r-- 1 root root  936 May 31 19:22 01_data_pipeline.py
# -rw-r--r-- 1 root root 3062 May 31 19:22 02_train_pipeline.py
# -rw-r--r-- 1 root root 3736 May 31 19:22 03_eval_pipeline.py
# drwxr-xr-x 2 root root 4096 May 31 19:22 data
# drwxr-xr-x 6 root root 4096 May 31 19:22 fashion_mnist_pro
# drwxr-xr-x 8 root root 4096 May 31 19:22 .git
# -rw-r--r-- 1 root root   40 May 31 19:22 .gitignore
# drwxr-xr-x 2 root root 4096 May 31 19:22 models
# drwxr-xr-x 2 root root 4096 May 31 19:22 outputs
# -rw-r--r-- 1 root root 2392 May 31 19:22 README.md
# -rw-r--r-- 1 root root  131 May 31 19:22 requirements.txt

# %%
import os

# 1. Force Kaggle to go back to the main starting folder
os.chdir('/kaggle/working')

# 2. Delete the old, broken folder completely
# !rm -rf fashion_mnist_pro

# 3. Download the fresh, fixed version from GitHub
# !git clone https://github.com/MRoberto25/fashion_mnist_pro.git

# 4. Move into the fresh folder
os.chdir('/kaggle/working/fashion_mnist_pro')

# 5. Verify the files are there!
# !ls -la
# Out:
# Cloning into 'fashion_mnist_pro'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 78 (delta 32), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 28.97 KiB | 14.49 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# total 48
# drwxr-xr-x 6 root root 4096 May 31 19:22 .
# drwxr-xr-x 4 root root 4096 May 31 19:22 ..
# -rw-r--r-- 1 root root  936 May 31 19:22 01_data_pipeline.py
# -rw-r--r-- 1 root root 3029 May 31 19:22 02_train_pipeline.py
# -rw-r--r-- 1 root root 3704 May 31 19:22 03_eval_pipeline.py
# drwxr-xr-x 2 root root 4096 May 31 19:22 data
# drwxr-xr-x 8 root root 4096 May 31 19:22 .git
# -rw-r--r-- 1 root root   40 May 31 19:22 .gitignore
# drwxr-xr-x 2 root root 4096 May 31 19:22 models
# drwxr-xr-x 2 root root 4096 May 31 19:22 outputs
# -rw-r--r-- 1 root root 2392 May 31 19:22 README.md
# ...

# %%
import os

# Move inside the downloaded folder
os.chdir('/kaggle/working/fashion_mnist_pro')

print("Currently in:", os.getcwd())

# Step 1: Run the Data Pipeline
# !python 01_data_pipeline.py
# Out:
# Currently in: /kaggle/working/fashion_mnist_pro
# 2026-05-31 19:23:00.385127: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780255380.407953     697 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780255380.415332     697 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780255380.433043     697 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Step 2: Run the Training Pipeline
# !python 02_train_pipeline.py
# Out:
# 2026-05-31 19:23:06.478137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780255386.500257     715 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780255386.507893     715 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780255386.526917     715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Step 3: Run the Evaluation Pipeline
# !python 03_eval_pipeline.py
# Out:
# 2026-05-31 19:23:40.664330: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780255420.687178     876 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780255420.694782     876 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780255420.713494     876 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
